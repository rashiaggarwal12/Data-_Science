# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(df[['fare','age']])
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df.sample(6)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 777         1       3  female   5.0      0      0   12.4750        S   Third
# 779         1       1  female  43.0      0      1  211.3375        S   First
# 772         0       2  female  57.0      0      0   10.5000        S  Second
# 727         1       3  female   NaN      0      0    7.7375        Q   Third
# 383         1       1  female  35.0      1      0   52.0000        S   First
# 381         1       3  female   1.0      0      2   15.7417        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 777  child       False  NaN  Southampton   yes   True
# 779  woman       False    B  Southampton   yes  False
# 772  woman       False    E  Southampton    no   True
# 727  woman       False  NaN   Queenstown   yes   True
# 383  woman       False  NaN  Southampton   yes  False
# 381  child       False  NaN    Cherbourg   yes  False

# %%
df.describe() #gives descriptive dataset
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
gender_counts=df['sex'].value_counts()
print(gender_counts)
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="sex")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df,x="class",hue="survived")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df,x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=df,x="embark_town") #town from where most people embark
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
sns.countplot(data=df,x="sex",hue ='survived') # differ of survival rate bw males and females
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#which class passengers not survived more in numbers
sns.countplot(data=df,x="pclass",hue ='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
#which town embarked passesngers survived least in numbers
sns.countplot(data=df,x="embark_town",hue ='survived')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
#avg fare was high for which gender

# %%
sns.barplot(data=df,x="sex",y="fare",ci=False)
# Out:
# <ipython-input-30-4454624c89e7>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df,x="sex",y="fare",ci=False)
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#relationship bw fare and survival. do passengers who paid higher fares have a better chance of survival

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df,x="survived",y="fare",ci=False)
# Out:
# <ipython-input-33-774470af2b87>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df,x="survived",y="fare",ci=False)
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.barplot(data=df,x="survived",y='fare',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
#investigate the relationship bw age and survival are younger passengers more likely to survive?

sns.barplot(data=df,x="survived",y='age',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.pointplot(data=df,x='survived',y='age',errorbar=('ci',False))
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>
