# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
x=np.random.randint(1,20,100)
y1=x+5
y2=x**2
y3=x**3

# %%
#scatter plot
plt.figure(figsize=(10,3))
plt.scatter(x,y1,c='g')
plt.scatter(x,y2,c='r')
plt.scatter(x,y3,c='b')
plt.title('scatter plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.scatter(x,y1,marker='*',c='g',s=100)

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.scatter(x,y2,marker='.',c='r',s=200)
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.scatter(x,y3,marker='^',c='b',s=20)
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.plot(x,y1,color='g',linestyle=':',linewidth=2)

plt.plot(x,y2,color='r',linestyle='-',linewidth=2)

plt.plot(x,y3,color='b',linestyle='dashed',linewidth=2)
plt.title('line plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,3,1)
plt.plot(x,y1,c='g',linestyle=':',linewidth=2)
plt.title('x vs y1')
# Out:
# Text(0.5, 1.0, 'x vs y1')

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,3,1)
plt.plot(x,y2,c='g',linestyle=':',linewidth=2)
plt.title('x vs y2')
# Out:
# Text(0.5, 1.0, 'x vs y2')

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,3,1)
plt.plot(x,y3,c='g',linestyle=':',linewidth=2)
plt.title('x vs y3')
# Out:
# Text(0.5, 1.0, 'x vs y3')

# %%
#bar plot
student= {'bob':87,'matt':56,'sam':27}
names=list(student.keys())
values=list(student.values())
plt.figure(figsize=(10,2))
plt.bar(names,values,color=['r','g','b'])
plt.title('bar plot')
plt.xticks(rotation=45)
plt.yticks(np.arange(0,101,10))
# Out:
# ([<matplotlib.axis.YTick at 0x7b9b091d59d0>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 10, '10'),
#   Text(0, 20, '20'),
#   Text(0, 30, '30'),
#   Text(0, 40, '40'),
#   Text(0, 50, '50'),
#   Text(0, 60, '60'),
#   Text(0, 70, '70'),
#   Text(0, 80, '80'),
#   Text(0, 90, '90'),
#   Text(0, 100, '100')])

# %%
#histogram
data=[1,3,3,3,9,5,4,4,8,8,8,6,7]
plt.figure(figsize=(10,3))
plt.hist(data)
# Out:
# (array([1., 0., 3., 2., 0., 1., 1., 1., 3., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
d=np.array([-100,500,600,1000,200])
plt.figure(figsize=(10,2))
sns.boxplot(d)
# Out:
# <Axes: >

# %%
#pie
f=['apple','orange','banana']
d=[60,20,10]

# %%
#pie
f=['apple','orange','banana']
d=[60,20,10]

# %%
plt.pie(d,labels=f)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b9b09133d50>,
# ...
#  [Text(-0.5500000555209213, 0.9526279121078616, 'apple'),
#   Text(0.19101348711923324, -1.0832884416158748, 'orange'),
#   Text(1.0336617954935041, -0.37622239770798543, 'banana')])

# %%
plt.pie(d,labels=f,autopct='%2.2f%%',)
# Out:
# ([<matplotlib.patches.Wedge at 0x7b9b08f6a610>,
# ...
#  [Text(-0.5500000555209213, 0.9526279121078616, 'apple'),
#   Text(0.19101348711923324, -1.0832884416158748, 'orange'),
#   Text(1.0336617954935041, -0.37622239770798543, 'banana')],
#  [Text(-0.30000003028413885, 0.5196152247861062, '66.67%'),
#   Text(0.10418917479230903, -0.5908846045177498, '22.22%'),
#   Text(0.5638155248146386, -0.2052122169316284, '11.11%')])

# %%
data=pd.read_csv('/content/12. Seaborn_Batsman.csv')

# %%
data
# Out:
#      RunsScored  BallsFaced  BattingPosition Dismissal  Inning   Opposition  \
# 0            12          22                2       LBW       1    Sri Lanka
# 1            37          67                2    Caught       2    Sri Lanka
# 2            25          38                1   Run out       1    Sri Lanka
# 3            54          66                1    Bowled       1    Sri Lanka
# 4            31          46                1       LBW       2    Sri Lanka
# ..          ...         ...              ...       ...     ...          ...
# 203         140         107                3   Stumped       2  West Indies
# 204         157         129                3        NO       1  West Indies
# 205         107         119                3    Bowled       2  West Indies
# 206          16          17                3    Caught       1  West Indies
# 207          33          29                3        NO       2  West Indies
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# ...

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='RunsScored', y='BallsFaced', s=32)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
balls_faced_by_position = data.groupby('BattingPosition')['BallsFaced'].sum()

max_position = balls_faced_by_position.idxmax()
max_balls = balls_faced_by_position.max()

print(f"Position {max_position} faced the most balls: {max_balls}")
# Out:
# Position 3 faced the most balls: 8645

# %%
balls_faced_by_position = data.groupby('BattingPosition')['RunsScored'].sum()

# Find the position with the maximum balls faced
max_position = balls_faced_by_position.idxmax()
max_balls = balls_faced_by_position.max()

print(f"Position {max_position} scored the most runs: {max_balls}")
# Out:
# Position 3 scored the most runs: 8139
